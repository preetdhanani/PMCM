# %% [markdown]
# # Clustering on Iris Data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
X = sns.load_dataset('iris')

# %%
y = X.species
X = X.drop('species',axis=1)

# %%
X.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
y.head()
# Out:
# 0    setosa
# 1    setosa
# 2    setosa
# 3    setosa
# 4    setosa
# Name: species, dtype: object

# %% [markdown]
# X is now the matrix with the feature values
#
# y is a series with the target value for each set of features
#
# Let's start with unsupervised learning and not use y

# %%
plt.scatter(X.petal_length,X.petal_width)

# %% [markdown]
# Let's find some clusters with sklearn

# %%
from sklearn.cluster import KMeans

clusterer = KMeans(
    n_clusters=150,
    init='random',
    random_state=42)

clusterer.fit(X)

y_pred = pd.Series(clusterer.predict(X))
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/base.py:1365: ConvergenceWarning: Number of distinct clusters (149) found smaller than n_clusters (150). Possibly due to duplicate points in X.
#   return fit_method(estimator, *args, **kwargs)

# %%
plt.scatter(X.petal_length,X.petal_width,c=y_pred)
