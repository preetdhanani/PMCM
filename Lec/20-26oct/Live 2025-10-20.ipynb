# %% [markdown]
# # Timestamps and CSV-Files continued

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
X = pd.read_csv('../Labs/Data/4Stu_2023_0118_0127  DataWithToolInfo.csv',
            sep=';',
            parse_dates=['timestamp_skv'],
            dayfirst=True
            )

# %%
X.describe()
# Out:
#                        timestamp_skv  timediff_skv  timediff_sensor  \
# count                          66703  66701.000000     66701.000000
# mean   2023-01-23 08:50:49.636001536      4.194825         4.194932
# min       2023-01-18 05:42:43.400000      0.000000         0.000000
# 25%       2023-01-18 21:15:11.400000      1.000000         1.500000
# 50%       2023-01-26 06:18:57.400000      2.000000         1.501000
# 75%       2023-01-26 16:41:58.400000      2.000000         1.579000
# max       2023-01-27 17:09:30.400000  29740.000000     29739.913000
# std                              NaN    173.450172       173.448476
#
#         SynchroDiff   ST_CH1_P_F0   ST_CH1_P_F1   ST_CH1_P_F2   ST_CH1_P_F3  \
# count  66703.000000  66703.000000  66703.000000  6.670300e+04  66703.000000
# mean       0.376575      0.001839      0.000014  2.278736e-07      0.059784
# min       -1.495000      0.000683      0.000000  2.691119e-08      0.047685
# ...

# %%
plt.plot(X.index,X.timestamp_skv)

# %%
delta = X.timestamp_skv.diff()/pd.Timedelta(days=1)

# %%
plt.plot(X.timestamp_skv,delta)

# %%
plt.plot(X.index,X.ST_CH1_P_F0)

# %%
plt.plot(X.timestamp_skv,X.ST_CH1_P_F0)

# %%
plt.scatter(X.ST_CH1_P_F0,X.ST_CH1_P_F2,c=X.timestamp_skv)
